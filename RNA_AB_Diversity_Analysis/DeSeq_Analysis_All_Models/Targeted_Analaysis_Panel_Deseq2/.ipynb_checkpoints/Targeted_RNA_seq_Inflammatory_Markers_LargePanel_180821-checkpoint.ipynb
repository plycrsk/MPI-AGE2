# %%
import pandas as pd

# %%
RNAseq_data = pd.read_csv("../Results/DiffExp_Analysis/DiffExp_age_plus_div_Q4.00_150821.csv")
Markers = pd.read_csv("Inflammatory_Markers_260721.csv", header=None)

# %%
Markers = Markers.dropna()

# %%
gene_dict = dict(zip(Markers[0], Markers[3]))

# %%
RNAseq_data = RNAseq_data[RNAseq_data['Unnamed: 0'].isin(Markers[0])]

# %%
RNAseq_data = RNAseq_data.reset_index()

# %%
RNAseq_data['Gene_Name'] = RNAseq_data['Unnamed: 0'].map(gene_dict)

# %%
RNAseq_data
# Out:
#     index          Unnamed: 0    baseMean  log2FoldChange     lfcSE      stat  \
# 0    2207  ENSNFUG00015003795   87.506134        0.001100  0.001676  0.656187
# 1    3358  ENSNFUG00015000538   19.668005        0.001149  0.003407  0.337162
# 2    4809  ENSNFUG00015000879    6.374039       -0.002666  0.004261 -0.625815
# 3    6239  ENSNFUG00015001596    0.697323        0.004698  0.015495  0.303180
# 4    8353  ENSNFUG00015011121  387.053542        0.000280  0.000793  0.352826
# 5    8882  ENSNFUG00015003470   82.004558       -0.002110  0.002774 -0.760499
# 6   11395  ENSNFUG00015015354   10.495331       -0.002707  0.005535 -0.489004
# 7   11599  ENSNFUG00015020257    2.827330       -0.002586  0.007179 -0.360285
# 8   13096  ENSNFUG00015020266    4.033079        0.000239  0.006019  0.039704
# 9   16839  ENSNFUG00015009023   29.476119       -0.001552  0.003934 -0.394471
# 10  20431  ENSNFUG00015009884  212.049664        0.000046  0.001904  0.024357
# 11  20507  ENSNFUG00015012860  357.980645        0.001219  0.001379  0.883940
# 12  21314  ENSNFUG00015015040  298.963019        0.000295  0.001031  0.286191
# 13  22518  ENSNFUG00015018588    3.543745       -0.000843  0.006033 -0.139808
# 14  23080  ENSNFUG00015019724    3.067490       -0.002871  0.006321 -0.454245
# 15  23089  ENSNFUG00015022267  209.432530        0.000943  0.000985  0.957069
# 16  23108  ENSNFUG00015014619    2.276235       -0.006475  0.007890 -0.820628
#
#       pvalue      padj Gene_Name
# 0   0.511704  0.999987      IL6R
# 1   0.735995  0.999987   IL22RA1
# 2   0.531436  0.999987     TGFB3
# 3   0.761753  0.999987      IL11
# 4   0.724219  0.999987     TGFB1
# 5   0.446957  0.999987    IL18R1
# 6   0.624839  0.999987       TNF
# 7   0.718634  0.999987   IL22RA1
# 8   0.968329  0.999987      IL10
# 9   0.693234  0.999987     IL1R2
# 10  0.980568  0.999987      IL6R
# 11  0.376728  0.999987      IL6R
# 12  0.774732  0.999987    TGFBR2
# 13  0.888812  0.999987       LTA
# 14  0.649653  0.999987     IL17D
# 15  0.338532  0.999987      IL6R
# 16  0.411858  0.999987      IFNG

# %%
RNAseq_data.to_csv("Inflammatory_Panel_Q4.00_180821.csv")
