# %%
import pandas as pd
import pingouin as pg
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
rnaseq = pd.read_csv("DEseq2_normalised_rna_counts_170621.csv", sep=',')
rnaseq = rnaseq.set_index('Unnamed: 0')
ab_div = pd.read_csv("Individual_Diversity_Spectra_Microbiome_130121.tsv", sep='\t')
fish_info = pd.read_csv("fish IDs.csv", header=None)
gene_list = pd.read_csv("killifish_human_ortho.csv")
orth_list = pd.read_csv("killifish_human_ortho.csv")

# %%
rnaseq = rnaseq.transpose()

# %%
rnaseq = np.log2(rnaseq + 1)

# %%
#select genes
#symbols to search for
gene_list = gene_list.dropna()
gene_list = gene_list[gene_list['HGNC.symbol'].str.contains('IL1|IL4|IL6|IL10|IL11|IL13|TNF|NFKB|CRP')]
gene_list = list(gene_list['Gene.stable.ID.1'])

# %%
rnaseq = rnaseq.loc[:, rnaseq.columns.isin(gene_list)]

# %%
# adding age
rnaseq['age'] = [1,1,1,0,0,0,0]

# %%
#Q_value
Q = 0.10
ab_div = ab_div[ab_div['Q'].isin([Q])]

# %%
ab_div_dict = dict(zip(ab_div['ID'], ab_div['D']))

# %%
rnaseq['diversity'] = rnaseq.index.map(ab_div_dict)

# %%
df = pd.DataFrame(columns=['n', 'r', 'CI95%', 'p-val'])

# %%
rnaseq['Age'] = ['16wk', '16wk', '16wk', '6wk', '6wk', '6wk', '6wk']

# %%
#will use partial_corr here instead
for i in rnaseq.columns[:-3]:
    result = pg.partial_corr(data=rnaseq, x=i, y='diversity', covar='age')
    df = df.append(result)
    
    plt.figure()
    sns_plot = sns.stripplot(x=i, y="diversity", data=rnaseq, hue="Age")
    fig = sns_plot.get_figure()
    fig.savefig("Plots/" + str(i) + "_220621.png", dpi=1000)
    plt.close
# Out:
# <ipython-input-302-36bef476fa2b>:6: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()

# %%
new_index = rnaseq.columns[:-3]

# %%
df.index = new_index

# %%
orth_dict_names = dict(zip(orth_list['Gene.stable.ID.1'], orth_list['HGNC.symbol']))

# %%
df['HGNC.symbol'] = df.index.map(orth_dict_names)

# %%
df.to_csv("Targeted_Partial_Correlation_Results.csv")
