# %%
import pandas as pd
import pingouin as pg
import seaborn as sns
import matplotlib.pyplot as plt

# %%
rnaseq = pd.read_csv("RNAseq_snakemake.tsv", sep='\t')
rnaseq = rnaseq.set_index('gene')
ab_div = pd.read_csv("Individual_Diversity_Spectra_Microbiome_130121.tsv", sep='\t')
fish_info = pd.read_csv("fish IDs.csv", header=None)
gene_list = pd.read_csv("killifish_human_ortho.csv")

# %%
rnaseq = rnaseq.transpose()

# %%
ID_dict = dict(zip(fish_info[3], fish_info[2]))

# %%
rnaseq.index = rnaseq.index.map(ID_dict)

# %%
#select genes
gene_list['HGNC.symbol']
# Out:
#            Gene.stable.ID HGNC.symbol Gene.stable.ID.1
# 0      ENSNFUG00015001778     MT-ATP6  ENSG00000198899
# 1      ENSNFUG00015000034      MT-ND6  ENSG00000198695
# 2      ENSNFUG00015000017      MT-CO1  ENSG00000198804
# 3      ENSNFUG00015000029      MT-ND4  ENSG00000198886
# 4      ENSNFUG00015000011      MT-ND2  ENSG00000198763
# ...                   ...         ...              ...
# 18468  ENSNFUG00015000628       ADCY7  ENSG00000121281
# 18469  ENSNFUG00015007487       ESPNL  ENSG00000144488
# 18470  ENSNFUG00015013427       CSF1R  ENSG00000182578
# 18471  ENSNFUG00015006647         DES  ENSG00000175084
# 18472  ENSNFUG00015008775        COG4  ENSG00000103051
#
# [18473 rows x 3 columns]

# %%
rnaseq = rnaseq.loc[:, rnaseq.columns.isin(genes)]
#rnaseq = rnaseq[genes]

# %%
# adding age
rnaseq['age'] = [1,1,1,0,0,0,0]

# %%
#Q_value
Q = 0.10
ab_div = ab_div[ab_div['Q'].isin([Q])]

# %%
ab_div_dict = dict(zip(ab_div['ID'], ab_div['D']))

# %%
rnaseq['diversity'] = rnaseq.index.map(ab_div_dict)

# %%
partial_corr_dict = {}

# %%
rnaseq['Age'] = ['16wk', '16wk', '16wk', '6wk', '6wk', '6wk', '6wk']

# %%
#will use partial_corr here instead
for i in rnaseq.columns[:-3]:
    result = pg.partial_corr(data=rnaseq, x=i, y='diversity', covar='age')
    partial_corr_dict[i] = result
    
    plt.figure()
    sns_plot = sns.stripplot(x=i, y="diversity", data=rnaseq, hue="Age")
    fig = sns_plot.get_figure()
    fig.savefig(str(i) + "_090621.png", dpi=1000)
# Out:
# <ipython-input-133-4dbff8354ba9>:6: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()

# %%
partial_corr_dict
# Out:
# {'ENSNFUG00015023667':          n         r          CI95%     p-val
#  pearson  7  0.481978  [-0.54, 0.93]  0.333015,
#  'ENSNFUG00015012874':          n         r          CI95%     p-val
#  pearson  7 -0.933134  [-0.99, -0.5]  0.006557,
#  'ENSNFUG00015021280':          n         r          CI95%     p-val
#  pearson  7  0.473171  [-0.55, 0.93]  0.343213,
#  'ENSNFUG00015005529':          n         r          CI95%     p-val
#  pearson  7 -0.496827  [-0.93, 0.53]  0.316077,
#  'ENSNFUG00015010037':          n         r          CI95%     p-val
#  pearson  7 -0.384043  [-0.91, 0.62]  0.452256,
#  'ENSNFUG00015001596':          n         r         CI95%     p-val
#  pearson  7  0.835936  [0.08, 0.98]  0.038168,
#  'ENSNFUG00015019483':          n         r          CI95%     p-val
#  pearson  7  0.440631  [-0.58, 0.92]  0.381828,
#  'ENSNFUG00015001125':          n         r          CI95%     p-val
#  pearson  7 -0.271244  [-0.89, 0.69]  0.603112,
#  'ENSNFUG00015002217':          n        r          CI95%     p-val
#  pearson  7 -0.05108  [-0.83, 0.79]  0.923446,
#  'ENSNFUG00015007109':          n         r          CI95%     p-val
#  pearson  7 -0.763023  [-0.97, 0.13]  0.077583,
#  'ENSNFUG00015003470':          n         r          CI95%     p-val
#  pearson  7  0.135947  [-0.76, 0.85]  0.797336,
#  'ENSNFUG00015015354':          n         r          CI95%     p-val
#  pearson  7  0.112854  [-0.77, 0.85]  0.831438,
#  'ENSNFUG00015020266':          n         r          CI95%     p-val
#  pearson  7  0.753827  [-0.15, 0.97]  0.083442,
#  'ENSNFUG00015006619':          n         r          CI95%     p-val
#  pearson  7  0.385977  [-0.62, 0.91]  0.449786,
#  'ENSNFUG00015007152':          n        r          CI95%     p-val
#  pearson  7 -0.06866  [-0.83, 0.79]  0.897172,
#  'ENSNFUG00015009023':          n         r         CI95%    p-val
#  pearson  7  0.329132  [-0.66, 0.9]  0.52413,
#  'ENSNFUG00015017365':          n         r         CI95%     p-val
#  pearson  7 -0.351086  [-0.9, 0.64]  0.495008,
#  'ENSNFUG00015007326':          n         r          CI95%     p-val
#  pearson  7  0.195253  [-0.73, 0.87]  0.710842,
#  'ENSNFUG00015022162':          n        r         CI95%    p-val
#  pearson  7  0.52619  [-0.5, 0.94]  0.28356,
#  'ENSNFUG00015018588':          n         r          CI95%     p-val
#  pearson  7  0.720877  [-0.22, 0.97]  0.105992,
#  'ENSNFUG00015013411':          n         r         CI95%     p-val
#  pearson  7 -0.255534  [-0.88, 0.7]  0.625041,
#  'ENSNFUG00015015410':          n         r          CI95%     p-val
#  pearson  7  0.363365  [-0.64, 0.91]  0.478941,
#  'ENSNFUG00015015383':          n         r          CI95%     p-val
#  pearson  7 -0.502941  [-0.93, 0.52]  0.309198,
#  'ENSNFUG00015015186':          n         r          CI95%     p-val
#  pearson  7  0.209967  [-0.73, 0.87]  0.689678}
