# %%
import pandas as pd
data = pd.read_csv("test.csv")

# %%
data
# Out:
#     Unnamed: 0 sample_name unit_name                         fq1  \
# 0            1  SRR5344335     lane1  SRR5344335_pass_1.fastq.gz
# 1            2  SRR5344336     lane1  SRR5344336_pass_1.fastq.gz
# 2            3  SRR5344337     lane1  SRR5344337_pass_1.fastq.gz
# 3            4  SRR5344338     lane1  SRR5344338_pass_1.fastq.gz
# 4            5  SRR5344340     lane1  SRR5344340_pass_1.fastq.gz
# 5            6  SRR5344341     lane1  SRR5344341_pass_1.fastq.gz
# 6            7  SRR5344342     lane1  SRR5344342_pass_1.fastq.gz
# 7            8  SRR5344343     lane1  SRR5344343_pass_1.fastq.gz
# 8            9  SRR5344344     lane1  SRR5344344_pass_1.fastq.gz
# 9           10  SRR5344345     lane1  SRR5344345_pass_1.fastq.gz
# 10          11  SRR5344347     lane1  SRR5344347_pass_1.fastq.gz
# 11          12  SRR5344348     lane1  SRR5344348_pass_1.fastq.gz
# 12          13  SRR5344349     lane1  SRR5344349_pass_1.fastq.gz
# ...

# %%
data2 = data.loc[1, ["adapters", "strandedness"]].dropna()

# %%
data2
# Out:
# Series([], Name: 1, dtype: object)

# %%
pd.isna(data2["adapters"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'adapters'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-c06df67a94a4> in <module>
# ...
